# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"]=(20,10)

# %%
df1= pd.read_csv("adult_dataset.csv")
df1
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# 0                      ?  Not-in-family  White  Female             0
# 1        Exec-managerial  Not-in-family  White  Female             0
# 2                      ?      Unmarried  Black  Female             0
# 3      Machine-op-inspct      Unmarried  White  Female             0
# 4         Prof-specialty      Own-child  White  Female             0
# ...                  ...            ...    ...     ...           ...
# 32556    Protective-serv  Not-in-family  White    Male             0
# 32557       Tech-support           Wife  White  Female             0
# 32558  Machine-op-inspct        Husband  White    Male             0
# 32559       Adm-clerical      Unmarried  White  Female             0
# 32560       Adm-clerical      Own-child  White    Male             0
#
#        capital.loss  hours.per.week native.country income
# 0              4356              40  United-States  <=50K
# 1              4356              18  United-States  <=50K
# 2              4356              40  United-States  <=50K
# 3              3900              40  United-States  <=50K
# 4              3900              40  United-States  <=50K
# ...             ...             ...            ...    ...
# 32556             0              40  United-States  <=50K
# 32557             0              38  United-States  <=50K
# 32558             0              40  United-States   >50K
# 32559             0              40  United-States  <=50K
# 32560             0              20  United-States  <=50K
#
# [32561 rows x 15 columns]

# %%
df1.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
df1[df1.workclass=="?"]
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 14      51         ?  172175     Doctorate             16       Never-married
# 24      61         ?  135285       HS-grad              9  Married-civ-spouse
# 44      71         ?  100820       HS-grad              9  Married-civ-spouse
# ...    ...       ...     ...           ...            ...                 ...
# 32533   35         ?  320084     Bachelors             13  Married-civ-spouse
# 32534   30         ?   33811     Bachelors             13       Never-married
# 32541   71         ?  287372     Doctorate             16  Married-civ-spouse
# 32543   41         ?  202822       HS-grad              9           Separated
# 32544   72         ?  129912       HS-grad              9  Married-civ-spouse
#
#       occupation   relationship                race     sex  capital.gain  \
# 0              ?  Not-in-family               White  Female             0
# 2              ?      Unmarried               Black  Female             0
# 14             ?  Not-in-family               White    Male             0
# 24             ?        Husband               White    Male             0
# 44             ?        Husband               White    Male             0
# ...          ...            ...                 ...     ...           ...
# 32533          ?           Wife               White  Female             0
# 32534          ?  Not-in-family  Asian-Pac-Islander  Female             0
# 32541          ?        Husband               White    Male             0
# 32543          ?  Not-in-family               Black  Female             0
# 32544          ?        Husband               White    Male             0
#
#        capital.loss  hours.per.week native.country income
# 0              4356              40  United-States  <=50K
# 2              4356              40  United-States  <=50K
# 14             2824              40  United-States   >50K
# 24             2603              32  United-States  <=50K
# 44             2489              15  United-States  <=50K
# ...             ...             ...            ...    ...
# 32533             0              55  United-States   >50K
# 32534             0              99  United-States  <=50K
# 32541             0              10  United-States   >50K
# 32543             0              32  United-States  <=50K
# 32544             0              25  United-States  <=50K
#
# [1836 rows x 15 columns]

# %%
df1= df1[df1.workclass!="?"]
df1= df1[df1.workclass!="Never-worked"]
df1
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 1       82   Private  132870       HS-grad              9             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# 5       34   Private  216864       HS-grad              9            Divorced
# 6       38   Private  150601          10th              6           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# 1        Exec-managerial  Not-in-family  White  Female             0
# 3      Machine-op-inspct      Unmarried  White  Female             0
# 4         Prof-specialty      Own-child  White  Female             0
# 5          Other-service      Unmarried  White  Female             0
# 6           Adm-clerical      Unmarried  White    Male             0
# ...                  ...            ...    ...     ...           ...
# 32556    Protective-serv  Not-in-family  White    Male             0
# 32557       Tech-support           Wife  White  Female             0
# 32558  Machine-op-inspct        Husband  White    Male             0
# 32559       Adm-clerical      Unmarried  White  Female             0
# 32560       Adm-clerical      Own-child  White    Male             0
#
#        capital.loss  hours.per.week native.country income
# 1              4356              18  United-States  <=50K
# 3              3900              40  United-States  <=50K
# 4              3900              40  United-States  <=50K
# 5              3770              45  United-States  <=50K
# 6              3770              40  United-States  <=50K
# ...             ...             ...            ...    ...
# 32556             0              40  United-States  <=50K
# 32557             0              38  United-States  <=50K
# 32558             0              40  United-States   >50K
# 32559             0              40  United-States  <=50K
# 32560             0              20  United-States  <=50K
#
# [30718 rows x 15 columns]

# %%
df1.groupby("native.country")["native.country"].agg('count')
df1=df1[df1["native.country"]!='?']
df1.groupby("native.country")["native.country"].agg('count')
# Out:
# native.country
# Cambodia                         18
# Canada                          107
# China                            68
# Columbia                         56
# Cuba                             92
# Dominican-Republic               67
# Ecuador                          27
# El-Salvador                     100
# England                          86
# France                           27
# Germany                         128
# Greece                           29
# Guatemala                        63
# Haiti                            42
# Holand-Netherlands                1
# Honduras                         12
# Hong                             19
# Hungary                          13
# India                           100
# Iran                             42
# Ireland                          24
# Italy                            68
# Jamaica                          80
# Japan                            59
# Laos                             17
# Mexico                          610
# Nicaragua                        33
# Outlying-US(Guam-USVI-etc)       14
# Peru                             30
# Philippines                     188
# Poland                           56
# Portugal                         34
# Puerto-Rico                     109
# Scotland                         11
# South                            71
# Taiwan                           42
# Thailand                         17
# Trinadad&Tobago                  18
# United-States                 27504
# Vietnam                          64
# Yugoslavia                       16
# Name: native.country, dtype: int64

# %%
df1["hours.per.week"].unique()
# Out:
# array([18, 40, 45, 20, 35, 55, 76, 50, 42, 25, 32, 90, 60, 48, 70, 52, 72,
#        39,  6, 65, 80, 67, 99, 30, 75, 12, 26, 10, 84, 38, 62, 44,  8, 28,
#        59,  5, 24, 57, 34, 37, 46, 56, 41, 98, 43, 15,  1, 36, 47, 68, 54,
#         2, 16,  9,  3,  4, 33, 23, 22, 64, 51, 19, 58, 63, 53, 96, 66, 21,
#         7, 13, 27, 14, 77, 31, 78, 11, 49, 17, 85, 87, 88, 73, 89, 97, 94,
#        29, 82, 86, 91, 81, 92, 61, 74, 95], dtype=int64)

# %%
df1.groupby("marital.status")["marital.status"].agg('count')
# Out:
# marital.status
# Divorced                  4214
# Married-AF-spouse           21
# Married-civ-spouse       14065
# Married-spouse-absent      370
# Never-married             9726
# Separated                  939
# Widowed                    827
# Name: marital.status, dtype: int64

# %%
df1.groupby("education.num")["education.num"].agg('count')
# Out:
# education.num
# 1       45
# 2      151
# 3      288
# 4      557
# 5      455
# 6      820
# 7     1048
# 8      377
# 9     9840
# 10    6678
# 11    1307
# 12    1008
# 13    5044
# 14    1627
# 15     542
# 16     375
# Name: education.num, dtype: int64

# %%
df1.groupby("occupation")["occupation"].agg('count')
# Out:
# occupation
# Adm-clerical         3721
# Armed-Forces            9
# Craft-repair         4030
# Exec-managerial      3992
# Farming-fishing       989
# Handlers-cleaners    1350
# Machine-op-inspct    1966
# Other-service        3212
# Priv-house-serv       143
# Prof-specialty       4038
# Protective-serv       644
# Sales                3584
# Tech-support          912
# Transport-moving     1572
# Name: occupation, dtype: int64

# %%
df1.groupby("relationship")["relationship"].agg('count')
# Out:
# relationship
# Husband           12463
# Not-in-family      7726
# Other-relative      889
# Own-child          4466
# Unmarried          3212
# Wife               1406
# Name: relationship, dtype: int64

# %%
df1.groupby("sex")["sex"].agg('count')
# Out:
# sex
# Female     9782
# Male      20380
# Name: sex, dtype: int64

# %%
df1.groupby("race")["race"].agg('count')
# Out:
# race
# Amer-Indian-Eskimo      286
# Asian-Pac-Islander      895
# Black                  2817
# Other                   231
# White                 25933
# Name: race, dtype: int64

# %%
df1.groupby("age")["age"].agg('count')
# Out:
# age
# 17    328
# 18    447
# 19    594
# 20    629
# 21    621
#      ...
# 84      8
# 85      3
# 86      1
# 88      3
# 90     35
# Name: age, Length: 72, dtype: int64

# %%
df1.groupby("income")["income"].agg('count')
# Out:
# income
# <=50K    22654
# >50K      7508
# Name: income, dtype: int64

# %%
df1=df1[df1.age<=60]
df1
df1.groupby("age")["age"].agg('count')
# Out:
# age
# 17    328
# 18    447
# 19    594
# 20    629
# 21    621
# 22    674
# 23    824
# 24    752
# 25    799
# 26    745
# 27    789
# 28    808
# 29    774
# 30    813
# 31    851
# 32    789
# 33    837
# 34    836
# 35    828
# 36    852
# 37    828
# 38    791
# 39    786
# 40    765
# 41    769
# 42    741
# 43    743
# 44    704
# 45    706
# 46    711
# 47    683
# 48    523
# 49    555
# 50    575
# 51    571
# 52    455
# 53    448
# 54    394
# 55    386
# 56    343
# 57    337
# 58    344
# 59    332
# 60    276
# Name: age, dtype: int64

# %%
df1=df1.drop(["fnlwgt","education.num","capital.gain","capital.loss"],axis='columns')

# %%
ages=df1.age
ages
# Out:
# 3        54
# 4        41
# 5        34
# 6        38
# 10       45
#          ..
# 32556    22
# 32557    27
# 32558    40
# 32559    58
# 32560    22
# Name: age, Length: 28356, dtype: int64

# %%
bins=[20,30,40,50,60]
age1=pd.cut(ages,bins)
age1=age1.cat.codes
age1
# Out:
# 3        3
# 4        2
# 5        1
# 6        1
# 10       2
#         ..
# 32556    0
# 32557    0
# 32558    1
# 32559    3
# 32560    0
# Length: 28356, dtype: int8

# %%
df1["age.group"]= age1

# %%
df1=df1.drop(["age"], axis='columns')

# %%
df1.groupby("education")["education"].agg('count')
# Out:
# education
# 10th             743
# 11th             995
# 12th             358
# 1st-4th          131
# 5th-6th          254
# 7th-8th          427
# 9th              404
# Assoc-acdm       985
# Assoc-voc       1254
# Bachelors       4809
# Doctorate        327
# HS-grad         9236
# Masters         1529
# Preschool         39
# Prof-school      492
# Some-college    6373
# Name: education, dtype: int64

# %%
primary=df1[df1.education=="1st-4th"]
primary
# Out:
#               workclass education         marital.status         occupation  \
# 26              Private   1st-4th     Married-civ-spouse       Craft-repair
# 219    Self-emp-not-inc   1st-4th     Married-civ-spouse   Transport-moving
# 1258   Self-emp-not-inc   1st-4th                Widowed       Craft-repair
# 2541   Self-emp-not-inc   1st-4th     Married-civ-spouse    Exec-managerial
# 3485            Private   1st-4th     Married-civ-spouse    Farming-fishing
# ...                 ...       ...                    ...                ...
# 31956           Private   1st-4th  Married-spouse-absent      Other-service
# 32108           Private   1st-4th     Married-civ-spouse      Other-service
# 32333           Private   1st-4th     Married-civ-spouse  Handlers-cleaners
# 32418           Private   1st-4th     Married-civ-spouse  Machine-op-inspct
# 32439           Private   1st-4th     Married-civ-spouse  Machine-op-inspct
#
#          relationship                race     sex  hours.per.week  \
# 26      Not-in-family               White    Male              32
# 219           Husband               White    Male              18
# 1258   Other-relative               White  Female              45
# 2541          Husband               White    Male              67
# 3485          Husband               White    Male              50
# ...               ...                 ...     ...             ...
# 31956       Own-child               Other  Female              35
# 32108            Wife  Asian-Pac-Islander  Female              40
# 32333  Other-relative               White    Male              40
# 32418         Husband               White    Male              40
# 32439            Wife  Amer-Indian-Eskimo  Female              35
#
#            native.country income  age.group
# 26                 Mexico  <=50K          1
# 219         United-States  <=50K          3
# 1258             Columbia  <=50K          3
# 2541                Italy   >50K          3
# 3485               Mexico  <=50K          2
# ...                   ...    ...        ...
# 31956  Dominican-Republic  <=50K          0
# 32108             Vietnam  <=50K          2
# 32333              Mexico  <=50K          0
# 32418            Portugal  <=50K          2
# 32439              Mexico  <=50K          0
#
# [131 rows x 11 columns]

# %%
primary["education"]='primary'
# Out:
# C:\Users\chait\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
primary
# Out:
#               workclass education         marital.status         occupation  \
# 26              Private   primary     Married-civ-spouse       Craft-repair
# 219    Self-emp-not-inc   primary     Married-civ-spouse   Transport-moving
# 1258   Self-emp-not-inc   primary                Widowed       Craft-repair
# 2541   Self-emp-not-inc   primary     Married-civ-spouse    Exec-managerial
# 3485            Private   primary     Married-civ-spouse    Farming-fishing
# ...                 ...       ...                    ...                ...
# 31956           Private   primary  Married-spouse-absent      Other-service
# 32108           Private   primary     Married-civ-spouse      Other-service
# 32333           Private   primary     Married-civ-spouse  Handlers-cleaners
# 32418           Private   primary     Married-civ-spouse  Machine-op-inspct
# 32439           Private   primary     Married-civ-spouse  Machine-op-inspct
#
#          relationship                race     sex  hours.per.week  \
# 26      Not-in-family               White    Male              32
# 219           Husband               White    Male              18
# 1258   Other-relative               White  Female              45
# 2541          Husband               White    Male              67
# 3485          Husband               White    Male              50
# ...               ...                 ...     ...             ...
# 31956       Own-child               Other  Female              35
# 32108            Wife  Asian-Pac-Islander  Female              40
# 32333  Other-relative               White    Male              40
# 32418         Husband               White    Male              40
# 32439            Wife  Amer-Indian-Eskimo  Female              35
#
#            native.country income  age.group
# 26                 Mexico  <=50K          1
# 219         United-States  <=50K          3
# 1258             Columbia  <=50K          3
# 2541                Italy   >50K          3
# 3485               Mexico  <=50K          2
# ...                   ...    ...        ...
# 31956  Dominican-Republic  <=50K          0
# 32108             Vietnam  <=50K          2
# 32333              Mexico  <=50K          0
# 32418            Portugal  <=50K          2
# 32439              Mexico  <=50K          0
#
# [131 rows x 11 columns]

# %%
secondary1=df1[df1.education=="5th-6th"]
secondary1["education"]='secondary'
secondary1
# Out:
# C:\Users\chait\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               workclass  education         marital.status         occupation  \
# 27              Private  secondary     Married-civ-spouse      Other-service
# 142             Private  secondary               Divorced       Craft-repair
# 226    Self-emp-not-inc  secondary     Married-civ-spouse              Sales
# 643             Private  secondary     Married-civ-spouse   Transport-moving
# 774    Self-emp-not-inc  secondary     Married-civ-spouse    Exec-managerial
# ...                 ...        ...                    ...                ...
# 31511           Private  secondary     Married-civ-spouse  Handlers-cleaners
# 31632           Private  secondary     Married-civ-spouse      Other-service
# 31670           Private  secondary          Never-married  Machine-op-inspct
# 32255         Local-gov  secondary          Never-married  Handlers-cleaners
# 32358           Private  secondary  Married-spouse-absent    Farming-fishing
#
#          relationship                race     sex  hours.per.week  \
# 27            Husband               White    Male              40
# 142     Not-in-family               White  Female              45
# 226           Husband               White    Male              50
# 643           Husband  Amer-Indian-Eskimo    Male              40
# 774           Husband               White    Male              67
# ...               ...                 ...     ...             ...
# 31511         Husband               Black    Male              52
# 31632         Husband               White    Male              40
# 31670       Own-child               White    Male              20
# 32255  Other-relative               White    Male              40
# 32358   Not-in-family               White    Male              40
#
#       native.country income  age.group
# 27            Greece  <=50K          2
# 142    United-States  <=50K          2
# 226           Mexico  <=50K          2
# 643    United-States  <=50K          2
# 774    United-States   >50K          3
# ...              ...    ...        ...
# 31511  United-States  <=50K          3
# 31632    El-Salvador  <=50K          0
# 31670  United-States  <=50K          2
# 32255      Guatemala   >50K          0
# 32358         Mexico  <=50K          0
#
# [254 rows x 11 columns]

# %%
secondary2=df1[df1.education=="7th-8th"]
secondary2["education"]='secondary'
secondary2
# Out:
# C:\Users\chait\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               workclass  education         marital.status         occupation  \
# 3               Private  secondary               Divorced  Machine-op-inspct
# 212             Private  secondary          Never-married  Handlers-cleaners
# 216             Private  secondary     Married-civ-spouse  Handlers-cleaners
# 218    Self-emp-not-inc  secondary     Married-civ-spouse       Craft-repair
# 277             Private  secondary     Married-civ-spouse    Farming-fishing
# ...                 ...        ...                    ...                ...
# 32168           Private  secondary     Married-civ-spouse       Craft-repair
# 32374           Private  secondary  Married-spouse-absent  Machine-op-inspct
# 32416         Local-gov  secondary          Never-married      Other-service
# 32445           Private  secondary               Divorced  Machine-op-inspct
# 32521           Private  secondary     Married-civ-spouse       Craft-repair
#
#          relationship   race     sex  hours.per.week native.country income  \
# 3           Unmarried  White  Female              40  United-States  <=50K
# 212     Not-in-family  Black    Male              40  United-States  <=50K
# 216           Husband  Other    Male              40    Puerto-Rico  <=50K
# 218           Husband  White    Male              40  United-States  <=50K
# 277           Husband  White    Male              40  United-States  <=50K
# ...               ...    ...     ...             ...            ...    ...
# 32168         Husband  White    Male              40  United-States  <=50K
# 32374   Not-in-family  White    Male              40  United-States  <=50K
# 32416  Other-relative  Black  Female              40  United-States  <=50K
# 32445   Not-in-family  White  Female              48  United-States  <=50K
# 32521         Husband  White    Male              40  United-States  <=50K
#
#        age.group
# 3              3
# 212            2
# 216            0
# 218            2
# 277            0
# ...          ...
# 32168          3
# 32374          3
# 32416          3
# 32445          3
# 32521          1
#
# [427 rows x 11 columns]

# %%
secondary3=df1[df1.education=="9th"]
secondary3["education"]='secondary'
secondary3
# Out:
# C:\Users\chait\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        workclass  education      marital.status         occupation  \
# 197    Local-gov  secondary             Widowed  Handlers-cleaners
# 963      Private  secondary  Married-civ-spouse      Other-service
# 1081     Private  secondary       Never-married  Machine-op-inspct
# 1110     Private  secondary            Divorced      Other-service
# 1116     Private  secondary       Never-married  Handlers-cleaners
# ...          ...        ...                 ...                ...
# 32166    Private  secondary  Married-civ-spouse  Machine-op-inspct
# 32263    Private  secondary  Married-civ-spouse  Machine-op-inspct
# 32316    Private  secondary       Never-married  Machine-op-inspct
# 32460    Private  secondary  Married-civ-spouse   Transport-moving
# 32474    Private  secondary  Married-civ-spouse       Craft-repair
#
#         relationship   race     sex  hours.per.week native.country income  \
# 197        Unmarried  White    Male              40  United-States   >50K
# 963          Husband  White    Male              40  United-States   >50K
# 1081   Not-in-family  White    Male              40  United-States  <=50K
# 1110   Not-in-family  White  Female              30  United-States  <=50K
# 1116       Own-child  White    Male              15  United-States  <=50K
# ...              ...    ...     ...             ...            ...    ...
# 32166        Husband  Black    Male              40  United-States  <=50K
# 32263        Husband  White    Male              45  United-States  <=50K
# 32316      Own-child  Black    Male              20  United-States  <=50K
# 32460        Husband  Black    Male              40  United-States  <=50K
# 32474        Husband  White    Male              48  United-States  <=50K
#
#        age.group
# 197            2
# 963            2
# 1081           0
# 1110           2
# 1116          -1
# ...          ...
# 32166          2
# 32263          3
# 32316          0
# 32460          1
# 32474          3
#
# [404 rows x 11 columns]

# %%
secondary4=df1[df1.education=="10th"]
secondary4["education"]='secondary'
secondary4
# Out:
# C:\Users\chait\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           workclass  education      marital.status         occupation  \
# 6           Private  secondary           Separated       Adm-clerical
# 28     Self-emp-inc  secondary       Never-married   Transport-moving
# 29          Private  secondary       Never-married     Prof-specialty
# 31     Self-emp-inc  secondary             Widowed    Exec-managerial
# 195         Private  secondary             Widowed       Adm-clerical
# ...             ...        ...                 ...                ...
# 32457       Private  secondary       Never-married      Other-service
# 32510       Private  secondary       Never-married       Adm-clerical
# 32513       Private  secondary            Divorced      Other-service
# 32529       Private  secondary  Married-civ-spouse   Transport-moving
# 32552       Private  secondary  Married-civ-spouse  Handlers-cleaners
#
#         relationship                race     sex  hours.per.week  \
# 6          Unmarried               White    Male              40
# 28     Not-in-family               White    Male              50
# 29     Not-in-family               White    Male              90
# 31         Unmarried               White  Female              50
# 195        Unmarried               White  Female              35
# ...              ...                 ...     ...             ...
# 32457      Own-child               White    Male              20
# 32510  Not-in-family               Black    Male              40
# 32513  Not-in-family               Black  Female              38
# 32529        Husband               White    Male              40
# 32552        Husband  Amer-Indian-Eskimo    Male              40
#
#            native.country income  age.group
# 6           United-States  <=50K          1
# 28          United-States   >50K          1
# 29          United-States   >50K          1
# 31          United-States   >50K          3
# 195         United-States  <=50K          0
# ...                   ...    ...        ...
# 32457       United-States  <=50K         -1
# 32510       United-States  <=50K          1
# 32513  Dominican-Republic  <=50K          2
# 32529       United-States  <=50K          1
# 32552       United-States  <=50K          1
#
# [743 rows x 11 columns]

# %%
HS1=df1[df1.education=="11th"]
HS1["education"]='High School'
HS1
# Out:
# C:\Users\chait\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               workclass    education         marital.status  \
# 16              Private  High School               Divorced
# 21              Private  High School              Separated
# 61         Self-emp-inc  High School          Never-married
# 241    Self-emp-not-inc  High School     Married-civ-spouse
# 247             Private  High School     Married-civ-spouse
# ...                 ...          ...                    ...
# 32420           Private  High School     Married-civ-spouse
# 32466  Self-emp-not-inc  High School  Married-spouse-absent
# 32499           Private  High School               Divorced
# 32502           Private  High School          Never-married
# 32525           Private  High School     Married-civ-spouse
#
#               occupation    relationship   race     sex  hours.per.week  \
# 16      Transport-moving   Not-in-family  White    Male              76
# 21                 Sales   Not-in-family  White  Female              42
# 61       Exec-managerial  Other-relative  White    Male              40
# 241         Craft-repair       Own-child  White    Male              55
# 247         Craft-repair         Husband  White    Male              40
# ...                  ...             ...    ...     ...             ...
# 32420      Other-service         Husband  White    Male              40
# 32466       Craft-repair   Not-in-family  White    Male              30
# 32499  Machine-op-inspct       Unmarried  White  Female              40
# 32502     Prof-specialty       Own-child  White    Male              20
# 32525              Sales         Husband  White    Male              40
#
#       native.country income  age.group
# 16     United-States   >50K          2
# 21     United-States  <=50K          0
# 61     United-States   >50K          2
# 241    United-States  <=50K         -1
# 247    United-States  <=50K          1
# ...              ...    ...        ...
# 32420  United-States  <=50K          1
# 32466       Honduras  <=50K          0
# 32499  United-States  <=50K          0
# 32502  United-States  <=50K         -1
# 32525  United-States  <=50K          3
#
# [995 rows x 11 columns]

# %%
HS2=df1[df1.education=="12th"]
HS2["education"]='High School'
HS2
# Out:
# C:\Users\chait\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           workclass    education      marital.status         occupation  \
# 178         Private  High School            Divorced       Craft-repair
# 954       Local-gov  High School  Married-civ-spouse   Transport-moving
# 1012        Private  High School       Never-married  Machine-op-inspct
# 1093        Private  High School       Never-married      Other-service
# 1187   Self-emp-inc  High School  Married-civ-spouse    Exec-managerial
# ...             ...          ...                 ...                ...
# 32354       Private  High School  Married-civ-spouse  Machine-op-inspct
# 32368       Private  High School       Never-married      Other-service
# 32410       Private  High School       Never-married       Adm-clerical
# 32482       Private  High School  Married-civ-spouse       Craft-repair
# 32538       Private  High School       Never-married    Protective-serv
#
#         relationship   race     sex  hours.per.week native.country income  \
# 178    Not-in-family  White    Male              42  United-States  <=50K
# 954          Husband  White    Male              40      Nicaragua   >50K
# 1012   Not-in-family  White    Male              40  United-States  <=50K
# 1093       Own-child  White  Female              25  United-States  <=50K
# 1187         Husband  White    Male              40  United-States  <=50K
# ...              ...    ...     ...             ...            ...    ...
# 32354        Husband  White    Male              40  United-States  <=50K
# 32368      Own-child  White    Male              12  United-States  <=50K
# 32410      Own-child  White    Male              35  United-States  <=50K
# 32482        Husband  White    Male              84  United-States  <=50K
# 32538      Own-child  Black    Male              35  United-States  <=50K
#
#        age.group
# 178            1
# 954            1
# 1012           0
# 1093          -1
# 1187           3
# ...          ...
# 32354          0
# 32368         -1
# 32410         -1
# 32482          1
# 32538          0
#
# [358 rows x 11 columns]

# %%
HSG=df1[df1.education=="HS-grad"]
HSG["education"]='High School Graduate'
HSG
# Out:
# C:\Users\chait\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               workclass             education      marital.status  \
# 5               Private  High School Graduate            Divorced
# 34     Self-emp-not-inc  High School Graduate       Never-married
# 36              Private  High School Graduate       Never-married
# 51              Private  High School Graduate             Widowed
# 71     Self-emp-not-inc  High School Graduate  Married-civ-spouse
# ...                 ...                   ...                 ...
# 32542         State-gov  High School Graduate           Separated
# 32549           Private  High School Graduate  Married-civ-spouse
# 32558           Private  High School Graduate  Married-civ-spouse
# 32559           Private  High School Graduate             Widowed
# 32560           Private  High School Graduate       Never-married
#
#               occupation   relationship   race     sex  hours.per.week  \
# 5          Other-service      Unmarried  White  Female              45
# 34       Exec-managerial  Not-in-family  Black    Male              50
# 36                 Sales  Not-in-family  White    Male              48
# 51                 Sales  Not-in-family  White  Female              72
# 71       Exec-managerial        Husband  White    Male              50
# ...                  ...            ...    ...     ...             ...
# 32542       Adm-clerical      Own-child  White  Female              40
# 32549  Machine-op-inspct        Husband  White    Male              40
# 32558  Machine-op-inspct        Husband  White    Male              40
# 32559       Adm-clerical      Unmarried  White  Female              40
# 32560       Adm-clerical      Own-child  White    Male              20
#
#       native.country income  age.group
# 5      United-States  <=50K          1
# 34     United-States   >50K          3
# 36     United-States   >50K          3
# 51     United-States   >50K          2
# 71     United-States   >50K          2
# ...              ...    ...        ...
# 32542  United-States  <=50K          2
# 32549         Mexico  <=50K          2
# 32558  United-States   >50K          1
# 32559  United-States  <=50K          3
# 32560  United-States  <=50K          0
#
# [9236 rows x 11 columns]

# %%
Bach1=df1[df1.education=="Bachelors"]
Bach1["education"]='Bachelors'
Bach1
# Out:
# C:\Users\chait\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        workclass  education      marital.status       occupation  \
# 12       Private  Bachelors             Widowed    Other-service
# 19       Private  Bachelors           Separated            Sales
# 20       Private  Bachelors       Never-married  Exec-managerial
# 33       Private  Bachelors            Divorced  Exec-managerial
# 40       Private  Bachelors            Divorced  Exec-managerial
# ...          ...        ...                 ...              ...
# 32507  Local-gov  Bachelors  Married-civ-spouse   Prof-specialty
# 32512    Private  Bachelors  Married-civ-spouse   Prof-specialty
# 32516  Local-gov  Bachelors       Never-married     Adm-clerical
# 32536    Private  Bachelors  Married-civ-spouse  Exec-managerial
# 32539    Private  Bachelors       Never-married  Exec-managerial
#
#         relationship                race     sex  hours.per.week  \
# 12     Not-in-family               White  Female              20
# 19     Not-in-family               White    Male              50
# 20     Not-in-family               White    Male              40
# 33     Not-in-family               White    Male              50
# 40         Unmarried               White    Male              50
# ...              ...                 ...     ...             ...
# 32507        Husband               White    Male              50
# 32512        Husband               White    Male              40
# 32516      Own-child               Black  Female              40
# 32536        Husband  Asian-Pac-Islander    Male              50
# 32539  Not-in-family               White  Female              55
#
#       native.country income  age.group
# 12     United-States   >50K          3
# 19     United-States   >50K          1
# 20     United-States   >50K          1
# 33     United-States   >50K          3
# 40     United-States   >50K          2
# ...              ...    ...        ...
# 32507  United-States  <=50K          1
# 32512  United-States  <=50K          2
# 32516  United-States  <=50K          0
# 32536          Japan   >50K          3
# 32539  United-States   >50K          1
#
# [4809 rows x 11 columns]

# %%
Bach2=df1[df1.education=="Prof-school"]
Bach2["education"]='Bachelors'
Bach2
# Out:
# C:\Users\chait\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               workclass  education      marital.status       occupation  \
# 11     Self-emp-not-inc  Bachelors       Never-married   Prof-specialty
# 15              Private  Bachelors            Divorced   Prof-specialty
# 32              Private  Bachelors            Divorced  Exec-managerial
# 37              Private  Bachelors       Never-married   Prof-specialty
# 50     Self-emp-not-inc  Bachelors       Never-married   Prof-specialty
# ...                 ...        ...                 ...              ...
# 31892  Self-emp-not-inc  Bachelors  Married-civ-spouse   Prof-specialty
# 31908           Private  Bachelors       Never-married   Prof-specialty
# 31918           Private  Bachelors  Married-civ-spouse  Exec-managerial
# 32290      Self-emp-inc  Bachelors  Married-civ-spouse   Prof-specialty
# 32449           Private  Bachelors  Married-civ-spouse   Prof-specialty
#
#         relationship                race     sex  hours.per.week  \
# 11     Not-in-family               White    Male              45
# 15     Not-in-family               White    Male              40
# 32     Not-in-family               White    Male              60
# 37     Not-in-family               White  Female              50
# 50     Not-in-family               White    Male              45
# ...              ...                 ...     ...             ...
# 31892        Husband               White    Male              70
# 31908      Own-child  Asian-Pac-Islander    Male              40
# 31918        Husband  Asian-Pac-Islander    Male              65
# 32290        Husband               White    Male              60
# 32449        Husband               White    Male              50
#
#       native.country income  age.group
# 11     United-States   >50K          1
# 15     United-States   >50K          2
# 32     United-States   >50K          3
# 37     United-States   >50K          3
# 50     United-States   >50K          1
# ...              ...    ...        ...
# 31892  United-States   >50K          3
# 31908  United-States  <=50K          0
# 31918          Japan   >50K          1
# 32290  United-States   >50K          3
# 32449  United-States   >50K          1
#
# [492 rows x 11 columns]

# %%
Mast=df1[df1.education=="Masters"]
Mast["education"]='Masters'
Mast
# Out:
# C:\Users\chait\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       workclass education      marital.status       occupation   relationship  \
# 13      Private   Masters           Separated  Exec-managerial  Not-in-family
# 17      Private   Masters            Divorced  Exec-managerial  Not-in-family
# 39      Private   Masters            Divorced   Prof-specialty  Not-in-family
# 41      Private   Masters            Divorced  Exec-managerial      Unmarried
# 43      Private   Masters            Divorced   Prof-specialty      Unmarried
# ...         ...       ...                 ...              ...            ...
# 32509   Private   Masters            Divorced            Sales  Not-in-family
# 32518   Private   Masters  Married-civ-spouse   Prof-specialty           Wife
# 32546   Private   Masters            Divorced    Other-service  Not-in-family
# 32554   Private   Masters       Never-married     Tech-support  Not-in-family
# 32555   Private   Masters  Married-civ-spouse  Exec-managerial        Husband
#
#                      race     sex  hours.per.week native.country income  \
# 13                  White    Male              55  United-States   >50K
# 17                  White    Male              50  United-States   >50K
# 39                  White  Female              40  United-States   >50K
# 41                  White  Female              40  United-States   >50K
# 43                  White  Female              40  United-States   >50K
# ...                   ...     ...             ...            ...    ...
# 32509               White  Female              50  United-States   >50K
# 32518               White  Female              22  United-States   >50K
# 32546               Other  Female              30  United-States  <=50K
# 32554  Asian-Pac-Islander    Male              11         Taiwan  <=50K
# 32555               White    Male              40  United-States   >50K
#
#        age.group
# 13             1
# 17             3
# 39             3
# 41             2
# 43             2
# ...          ...
# 32509          2
# 32518          2
# 32546          1
# 32554          1
# 32555          3
#
# [1529 rows x 11 columns]

# %%
Doc=df1[df1.education=="Doctorate"]
Doc["education"]='Doctorate'
Doc
# Out:
# C:\Users\chait\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               workclass  education      marital.status       occupation  \
# 10              Private  Doctorate            Divorced   Prof-specialty
# 38     Self-emp-not-inc  Doctorate       Never-married   Prof-specialty
# 99              Private  Doctorate  Married-civ-spouse   Prof-specialty
# 101             Private  Doctorate  Married-civ-spouse   Prof-specialty
# 183           State-gov  Doctorate       Never-married  Exec-managerial
# ...                 ...        ...                 ...              ...
# 32315         Local-gov  Doctorate  Married-civ-spouse  Exec-managerial
# 32350           Private  Doctorate  Married-civ-spouse   Prof-specialty
# 32443         Local-gov  Doctorate            Divorced  Exec-managerial
# 32477           Private  Doctorate            Divorced   Prof-specialty
# 32535           Private  Doctorate  Married-civ-spouse   Prof-specialty
#
#         relationship   race     sex  hours.per.week native.country income  \
# 10         Unmarried  Black  Female              35  United-States   >50K
# 38     Not-in-family  White  Female              60  United-States   >50K
# 99           Husband  White    Male              45  United-States   >50K
# 101          Husband  White    Male              55  United-States   >50K
# 183    Not-in-family  White  Female              50  United-States   >50K
# ...              ...    ...     ...             ...            ...    ...
# 32315        Husband  White    Male              60  United-States   >50K
# 32350        Husband  White    Male              45  United-States   >50K
# 32443  Not-in-family  White  Female              45  United-States   >50K
# 32477  Not-in-family  White  Female              50  United-States  <=50K
# 32535        Husband  White    Male              60  United-States   >50K
#
#        age.group
# 10             2
# 38             1
# 99             3
# 101            2
# 183            2
# ...          ...
# 32315          3
# 32350          2
# 32443          3
# 32477          2
# 32535          1
#
# [327 rows x 11 columns]

# %%
pre=df1[df1.education=="Preschool"]
pre["education"]='Pre-School'
pre
# Out:
# C:\Users\chait\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        workclass   education         marital.status         occupation  \
# 1106     Private  Pre-School  Married-spouse-absent  Machine-op-inspct
# 1153     Private  Pre-School     Married-civ-spouse      Other-service
# 1678     Private  Pre-School     Married-civ-spouse    Farming-fishing
# 3260     Private  Pre-School     Married-civ-spouse  Machine-op-inspct
# 4424   Local-gov  Pre-School          Never-married  Machine-op-inspct
# 5042   Local-gov  Pre-School     Married-civ-spouse      Other-service
# 6773     Private  Pre-School          Never-married      Other-service
# 7211     Private  Pre-School     Married-civ-spouse    Farming-fishing
# 7787     Private  Pre-School     Married-civ-spouse      Other-service
# 10198    Private  Pre-School     Married-civ-spouse    Farming-fishing
# 10374    Private  Pre-School          Never-married    Farming-fishing
# 11261    Private  Pre-School          Never-married    Farming-fishing
# 11856    Private  Pre-School          Never-married      Other-service
# 13209    Private  Pre-School          Never-married  Machine-op-inspct
# 14107    Private  Pre-School     Married-civ-spouse      Other-service
# 17344    Private  Pre-School          Never-married    Farming-fishing
# 18656    Private  Pre-School     Married-civ-spouse  Machine-op-inspct
# 20267    Private  Pre-School          Never-married    Farming-fishing
# 22845    Private  Pre-School          Never-married  Machine-op-inspct
# 23203  Local-gov  Pre-School          Never-married  Handlers-cleaners
# 23541    Private  Pre-School          Never-married      Other-service
# 23861    Private  Pre-School  Married-spouse-absent       Adm-clerical
# 24227    Private  Pre-School          Never-married    Farming-fishing
# 25289    Private  Pre-School     Married-civ-spouse       Craft-repair
# 25611    Private  Pre-School     Married-civ-spouse       Craft-repair
# 25737    Private  Pre-School     Married-civ-spouse  Machine-op-inspct
# 26087    Private  Pre-School              Separated      Other-service
# 26098    Private  Pre-School          Never-married      Other-service
# 26198    Private  Pre-School          Never-married      Other-service
# 26554    Private  Pre-School          Never-married  Handlers-cleaners
# 26799    Private  Pre-School          Never-married    Farming-fishing
# 27295    Private  Pre-School     Married-civ-spouse  Machine-op-inspct
# 27389    Private  Pre-School     Married-civ-spouse       Craft-repair
# 27931  Local-gov  Pre-School          Never-married       Adm-clerical
# 28939    Private  Pre-School          Never-married  Machine-op-inspct
# 31891  State-gov  Pre-School          Never-married      Other-service
# 32262    Private  Pre-School          Never-married      Other-service
# 32381    Private  Pre-School     Married-civ-spouse  Machine-op-inspct
# 32446    Private  Pre-School               Divorced      Other-service
#
#          relationship                race     sex  hours.per.week  \
# 1106    Not-in-family               White    Male              40
# 1153          Husband               White    Male              40
# 1678   Other-relative               White    Male              24
# 3260             Wife  Asian-Pac-Islander  Female              40
# 4424    Not-in-family               White  Female              35
# 5042          Husband               White    Male              40
# 6773   Other-relative               White  Female              35
# 7211          Husband               White    Male              40
# 7787    Not-in-family               White    Male              40
# 10198         Husband               White    Male              60
# 10374   Not-in-family               White    Male              40
# 11261   Not-in-family               White    Male              50
# 11856       Own-child               White    Male              32
# 13209   Not-in-family               White    Male              40
# 14107         Husband               White    Male              40
# 17344   Not-in-family               White    Male              50
# 18656            Wife               White  Female              40
# 20267   Not-in-family               White    Male              36
# 22845       Own-child               White  Female              30
# 23203       Own-child               White  Female              30
# 23541   Not-in-family               White  Female              12
# 23861       Own-child               White    Male              40
# 24227   Not-in-family               White    Male              35
# 25289         Husband  Asian-Pac-Islander    Male              40
# 25611         Husband               White    Male              40
# 25737         Husband               White    Male              40
# 26087       Unmarried               White  Female              40
# 26098       Own-child               White  Female              15
# 26198   Not-in-family  Asian-Pac-Islander  Female              40
# 26554   Not-in-family               White    Male              25
# 26799   Not-in-family               White    Male              36
# 27295         Husband               White    Male              40
# 27389         Husband  Asian-Pac-Islander    Male              40
# 27931       Own-child               Black  Female              25
# 28939   Not-in-family               Black    Male              40
# 31891   Not-in-family               White    Male              24
# 32262   Not-in-family               White  Female              20
# 32381  Other-relative               Black    Male              75
# 32446   Not-in-family               Other    Male              72
#
#            native.country income  age.group
# 1106               Mexico  <=50K          0
# 1153               Mexico  <=50K          1
# 1678               Mexico  <=50K          0
# 3260             Cambodia  <=50K          1
# 4424        United-States  <=50K          3
# 5042        United-States  <=50K          3
# 6773               Mexico  <=50K          1
# 7211               Mexico  <=50K          1
# 7787          El-Salvador  <=50K          3
# 10198       United-States  <=50K          3
# 10374              Mexico  <=50K          0
# 11261              Mexico  <=50K          0
# 11856       United-States  <=50K         -1
# 13209  Dominican-Republic  <=50K          3
# 14107              Mexico  <=50K          3
# 17344              Mexico  <=50K          0
# 18656              Mexico  <=50K          2
# 20267              Mexico  <=50K          0
# 22845       United-States  <=50K          0
# 23203       United-States  <=50K          2
# 23541       United-States  <=50K          1
# 23861       United-States  <=50K          1
# 24227              Mexico  <=50K          0
# 25289               India  <=50K          3
# 25611           Nicaragua  <=50K          2
# 25737              Mexico  <=50K          1
# 26087         El-Salvador  <=50K          2
# 26098       United-States  <=50K          0
# 26198                Laos  <=50K          0
# 26554       United-States  <=50K          2
# 26799                Hong  <=50K         -1
# 27295         El-Salvador  <=50K          3
# 27389               China  <=50K          3
# 27931       United-States  <=50K          1
# 28939         Puerto-Rico  <=50K          1
# 31891       United-States  <=50K          1
# 32262       United-States  <=50K          1
# 32381  Dominican-Republic  <=50K          2
# 32446              Mexico  <=50K          1

# %%
Drop=df1[df1.education=="Some-college"]
Drop["education"]='Dropout'
Drop
# Out:
# C:\Users\chait\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               workclass education      marital.status        occupation  \
# 4               Private   Dropout           Separated    Prof-specialty
# 23              Private   Dropout  Married-civ-spouse  Transport-moving
# 30              Private   Dropout           Separated     Other-service
# 42              Private   Dropout            Divorced      Adm-clerical
# 53              Private   Dropout       Never-married   Exec-managerial
# ...                 ...       ...                 ...               ...
# 32530           Private   Dropout       Never-married      Adm-clerical
# 32537           Private   Dropout            Divorced      Adm-clerical
# 32550         State-gov   Dropout            Divorced      Adm-clerical
# 32551  Self-emp-not-inc   Dropout  Married-civ-spouse      Craft-repair
# 32556           Private   Dropout       Never-married   Protective-serv
#
#          relationship   race     sex  hours.per.week native.country income  \
# 4           Own-child  White  Female              40  United-States  <=50K
# 23            Husband  White    Male              40  United-States  <=50K
# 30      Not-in-family  White    Male              40  United-States   >50K
# 42          Unmarried  White  Female              40  United-States   >50K
# 53      Not-in-family  White  Female              40  United-States   >50K
# ...               ...    ...     ...             ...            ...    ...
# 32530       Own-child  White    Male              40  United-States  <=50K
# 32537       Unmarried  White  Female              39  United-States  <=50K
# 32550  Other-relative  White  Female              40  United-States  <=50K
# 32551         Husband  White    Male              50  United-States  <=50K
# 32556   Not-in-family  White    Male              40  United-States  <=50K
#
#        age.group
# 4              2
# 23             3
# 30             0
# 42             3
# 53             2
# ...          ...
# 32530          0
# 32537          1
# 32550          2
# 32551          2
# 32556          0
#
# [6373 rows x 11 columns]

# %%
df2 = pd.concat([primary,secondary1,secondary2,secondary3,secondary4,HS1,HS2,HSG,Bach1,Bach2,Mast,Doc,pre,Drop])

# %%
df2
# Out:
#               workclass education      marital.status        occupation  \
# 26              Private   primary  Married-civ-spouse      Craft-repair
# 219    Self-emp-not-inc   primary  Married-civ-spouse  Transport-moving
# 1258   Self-emp-not-inc   primary             Widowed      Craft-repair
# 2541   Self-emp-not-inc   primary  Married-civ-spouse   Exec-managerial
# 3485            Private   primary  Married-civ-spouse   Farming-fishing
# ...                 ...       ...                 ...               ...
# 32530           Private   Dropout       Never-married      Adm-clerical
# 32537           Private   Dropout            Divorced      Adm-clerical
# 32550         State-gov   Dropout            Divorced      Adm-clerical
# 32551  Self-emp-not-inc   Dropout  Married-civ-spouse      Craft-repair
# 32556           Private   Dropout       Never-married   Protective-serv
#
#          relationship   race     sex  hours.per.week native.country income  \
# 26      Not-in-family  White    Male              32         Mexico  <=50K
# 219           Husband  White    Male              18  United-States  <=50K
# 1258   Other-relative  White  Female              45       Columbia  <=50K
# 2541          Husband  White    Male              67          Italy   >50K
# 3485          Husband  White    Male              50         Mexico  <=50K
# ...               ...    ...     ...             ...            ...    ...
# 32530       Own-child  White    Male              40  United-States  <=50K
# 32537       Unmarried  White  Female              39  United-States  <=50K
# 32550  Other-relative  White  Female              40  United-States  <=50K
# 32551         Husband  White    Male              50  United-States  <=50K
# 32556   Not-in-family  White    Male              40  United-States  <=50K
#
#        age.group
# 26             1
# 219            3
# 1258           3
# 2541           3
# 3485           2
# ...          ...
# 32530          0
# 32537          1
# 32550          2
# 32551          2
# 32556          0
#
# [26117 rows x 11 columns]

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#               workclass education      marital.status        occupation  \
# 0               Private   primary  Married-civ-spouse      Craft-repair
# 1      Self-emp-not-inc   primary  Married-civ-spouse  Transport-moving
# 2      Self-emp-not-inc   primary             Widowed      Craft-repair
# 3      Self-emp-not-inc   primary  Married-civ-spouse   Exec-managerial
# 4               Private   primary  Married-civ-spouse   Farming-fishing
# ...                 ...       ...                 ...               ...
# 26112           Private   Dropout       Never-married      Adm-clerical
# 26113           Private   Dropout            Divorced      Adm-clerical
# 26114         State-gov   Dropout            Divorced      Adm-clerical
# 26115  Self-emp-not-inc   Dropout  Married-civ-spouse      Craft-repair
# 26116           Private   Dropout       Never-married   Protective-serv
#
#          relationship   race     sex  hours.per.week native.country income  \
# 0       Not-in-family  White    Male              32         Mexico  <=50K
# 1             Husband  White    Male              18  United-States  <=50K
# 2      Other-relative  White  Female              45       Columbia  <=50K
# 3             Husband  White    Male              67          Italy   >50K
# 4             Husband  White    Male              50         Mexico  <=50K
# ...               ...    ...     ...             ...            ...    ...
# 26112       Own-child  White    Male              40  United-States  <=50K
# 26113       Unmarried  White  Female              39  United-States  <=50K
# 26114  Other-relative  White  Female              40  United-States  <=50K
# 26115         Husband  White    Male              50  United-States  <=50K
# 26116   Not-in-family  White    Male              40  United-States  <=50K
#
#        age.group
# 0              1
# 1              3
# 2              3
# 3              3
# 4              2
# ...          ...
# 26112          0
# 26113          1
# 26114          2
# 26115          2
# 26116          0
#
# [26117 rows x 11 columns]

# %%
df_temp=df2[df2.income == ">50K"]
df_temp
# Out:
#               workclass education         marital.status         occupation  \
# 3      Self-emp-not-inc   primary     Married-civ-spouse    Exec-managerial
# 16              Private   primary     Married-civ-spouse  Machine-op-inspct
# 43              Private   primary     Married-civ-spouse    Farming-fishing
# 58              Private   primary     Married-civ-spouse    Exec-managerial
# 80              Private   primary     Married-civ-spouse       Craft-repair
# ...                 ...       ...                    ...                ...
# 26090           Private   Dropout     Married-civ-spouse      Other-service
# 26092           Private   Dropout     Married-civ-spouse       Craft-repair
# 26097  Self-emp-not-inc   Dropout  Married-spouse-absent       Craft-repair
# 26101           Private   Dropout     Married-civ-spouse              Sales
# 26111           Private   Dropout     Married-civ-spouse    Exec-managerial
#
#       relationship   race   sex  hours.per.week native.country income  \
# 3          Husband  White  Male              67          Italy   >50K
# 16         Husband  White  Male              40         Mexico   >50K
# 43         Husband  White  Male              56         Mexico   >50K
# 58         Husband  White  Male              50  United-States   >50K
# 80         Husband  Black  Male              40          Haiti   >50K
# ...            ...    ...   ...             ...            ...    ...
# 26090      Husband  White  Male              47  United-States   >50K
# 26092      Husband  White  Male              89  United-States   >50K
# 26097    Own-child  White  Male              60  United-States   >50K
# 26101      Husband  White  Male              45  United-States   >50K
# 26111      Husband  White  Male              48  United-States   >50K
#
#        age.group
# 3              3
# 16             2
# 43             3
# 58             3
# 80             3
# ...          ...
# 26090          2
# 26092          2
# 26097          0
# 26101          2
# 26111          2
#
# [6479 rows x 11 columns]

# %% [markdown]
# grp2=df2.groupby("sex")
# number=[]
# for sex, df_temp in grp2:
#     number.append(df_temp["sex"].count())
#
# plt.rcParams['patch.edgecolor'] = 'black'
# cols=['c','m']
# plt.pie(number, labels=['female','male'], colors=cols)
# plt.title("different sex woking above 50K")
# plt.show()

# %%
grp2=df2.groupby("race")
number=[]
for sex, df_temp in grp2:
    number.append(df_temp["race"].count())

plt.rcParams['patch.edgecolor'] = 'black'
cols=['c','m','k','b','g']
plt.pie(number, labels=['White', 'Asian-Pac-Islander', 'Other', 'Black','Amer-Indian-Eskimo'], colors=cols)
plt.title("different races woking above 50K")
plt.show()

# %%
df_temp["education"].unique()
# Out:
# array(['primary', 'secondary', 'High School', 'High School Graduate',
#        'Bachelors', 'Masters', 'Doctorate', 'Pre-School', 'Dropout'],
#       dtype=object)

# %%
grp2=df2.groupby("education")
number=[]
for sex, df_temp in grp2:
    number.append(df_temp["education"].count())

plt.rcParams['patch.edgecolor'] = 'black'
cols=['c','m','r','k','b','tab:blue', 'tab:orange', 'tab:green','g']
plt.pie(number, labels=['primary', 'secondary', 'High School', 'High School Graduate', 'Bachelors', 'Masters', 'Doctorate', 'Pre-School', 'Dropout'], colors=cols)
plt.title("different people with education qualification woking above 50K")
plt.show()

# %%
df_temp2= df2.groupby(["sex","education"]).size()
df_temp2
# Out:
# sex     education
# Female  Bachelors               1569
#         Doctorate                 72
#         Dropout                 2388
#         High School              471
#         High School Graduate    2881
#         Masters                  476
#         Pre-School                12
#         primary                   32
#         secondary                484
# Male    Bachelors               3732
#         Doctorate                255
#         Dropout                 3985
#         High School              882
#         High School Graduate    6355
#         Masters                 1053
#         Pre-School                27
#         primary                   99
#         secondary               1344
# dtype: int64

# %%
df_temp2= df2.groupby(["income","workclass"]).size()
df_temp2
# Out:
# income  workclass
# <=50K   Federal-gov           484
#         Local-gov            1218
#         Private             15316
#         Self-emp-inc          382
#         Self-emp-not-inc     1408
#         State-gov             823
#         Without-pay             7
# >50K    Federal-gov           313
#         Local-gov             537
#         Private              4248
#         Self-emp-inc          485
#         Self-emp-not-inc      592
#         State-gov             304
# dtype: int64

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()
e1=le.fit_transform(df2.workclass)
e2=le.fit_transform(df2.education)
e3=le.fit_transform(df2["marital.status"])
e4=le.fit_transform(df2.occupation)
e5=le.fit_transform(df2.relationship)
e6=le.fit_transform(df2.race)
e7=le.fit_transform(df2.sex)
e8=le.fit_transform(df2["native.country"])
e9=le.fit_transform(df2.income)
e8
# Out:
# array([25, 38,  3, ..., 38, 38, 38])

# %%
features = list(zip(e1,e2,e3,e4,e5,e6,e7,df2["hours.per.week"],e8,df2["age.group"]))
print(features)
# Out:
# [(2, 7, 2, 2, 1, 4, 1, 32, 25, 1), (4, 7, 2, 13, 0, 4, 1, 18, 38, 3), (4, 7, 6, 2, 2, 4, 0, 45, 3, 3), (4, 7, 2, 3, 0, 4, 1, 67, 21, 3), (2, 7, 2, 4, 0, 4, 1, 50, 25, 2), (2, 7, 4, 2, 1, 4, 1, 40, 12, 1), (2, 7, 2, 6, 0, 4, 1, 40, 25, 3), (2, 7, 3, 2, 4, 4, 1, 40, 38, 2), (2, 7, 6, 8, 1, 2, 0, 30, 38, 3), (2, 7, 3, 8, 1, 4, 0, 40, 12, 1), (2, 7, 2, 2, 0, 4, 1, 35, 25, 2), (2, 7, 2, 6, 0, 4, 1, 40, 25, 1), (2, 7, 2, 2, 0, 4, 1, 45, 25, 1), (2, 7, 3, 6, 4, 4, 0, 40, 5, 1), (2, 7, 0, 2, 4, 4, 1, 40, 31, 3), (2, 7, 4, 11, 3, 4, 1, 40, 38, 2), (2, 7, 2, 6, 0, 4, 1, 40, 25, 2), (2, 7, 4, 6, 1, 4, 0, 40, 7, 2), (2, 7, 2, 6, 0, 4, 1, 43, 25, 0), (2, 7, 2, 2, 0, 1, 1, 40, 0, 1), (2, 7, 2, 2, 0, 4, 1, 40, 38, 3), (2, 7, 6, 7, 4, 3, 0, 30, 25, 2), (4, 7, 3, 2, 1, 4, 1, 40, 25, 1), (2, 7, 4, 7, 3, 4, 1, 10, 38, 2), (2, 7, 4, 7, 3, 3, 1, 35, 5, 0), (2, 7, 2, 2, 0, 4, 1, 40, 31, 2), (2, 7, 4, 6, 3, 4, 1, 40, 32, 2), (2, 7, 2, 7, 0, 4, 1, 38, 4, 3), (2, 7, 4, 8, 1, 4, 0, 40, 12, 0), (2, 7, 2, 4, 0, 4, 1, 85, 25, 1), (2, 7, 2, 6, 0, 4, 1, 40, 25, 3), (2, 7, 5, 9, 4, 2, 0, 40, 38, 2), (2, 7, 5, 6, 3, 4, 0, 40, 12, 2), (2, 7, 6, 9, 4, 4, 0, 21, 25, 2), (2, 7, 2, 2, 0, 4, 1, 40, 25, 3), (2, 7, 2, 5, 0, 4, 1, 40, 25, 1), (2, 7, 2, 5, 0, 4, 1, 40, 25, 1), (2, 7, 2, 4, 0, 4, 1, 40, 25, 2), (2, 7, 3, 4, 4, 4, 1, 40, 25, 2), (2, 7, 2, 7, 0, 3, 1, 40, 5, 3), (2, 7, 4, 7, 1, 4, 1, 20, 7, 0), (2, 7, 0, 8, 4, 4, 0, 30, 4, 3), (2, 7, 2, 7, 0, 4, 1, 53, 25, 1), (2, 7, 2, 4, 0, 4, 1, 56, 25, 3), (2, 7, 4, 6, 1, 4, 0, 40, 25, 0), (2, 7, 4, 4, 4, 4, 1, 77, 25, 0), (2, 7, 2, 7, 5, 4, 0, 25, 7, 2), (2, 7, 2, 4, 0, 4, 1, 40, 38, 3), (2, 7, 2, 2, 0, 3, 1, 50, 32, 3), (2, 7, 2, 2, 0, 4, 1, 35, 25, 1), (2, 7, 3, 7, 1, 4, 1, 40, 12, 1), (2, 7, 5, 6, 4, 4, 1, 40, 38, 3), (2, 7, 4, 4, 1, 3, 1, 50, 25, 1), (2, 7, 4, 7, 1, 4, 1, 45, 7, 1), (2, 7, 4, 2, 1, 4, 1, 40, 12, 0), (2, 7, 4, 8, 1, 4, 0, 40, 12, 0), (4, 7, 2, 11, 0, 4, 1, 35, 25, 3), (1, 7, 6, 5, 4, 2, 1, 40, 38, 3), (2, 7, 2, 3, 0, 4, 1, 50, 38, 3), (2, 7, 4, 7, 2, 4, 0, 25, 7, 1), (2, 7, 4, 5, 1, 4, 1, 37, 25, 1), (2, 7, 0, 2, 1, 3, 1, 38, 5, 3), (2, 7, 2, 4, 0, 4, 1, 96, 25, 0), (2, 7, 2, 7, 0, 2, 1, 35, 32, 3), (2, 7, 3, 4, 1, 4, 1, 12, 25, 2), (2, 7, 2, 5, 0, 4, 1, 22, 38, 3), (2, 7, 2, 4, 0, 4, 1, 45, 25, 1), (2, 7, 5, 5, 4, 4, 1, 35, 15, 1), (2, 7, 2, 7, 5, 4, 0, 40, 38, 2), (2, 7, 2, 10, 2, 4, 1, 40, 25, 2), (2, 7, 4, 6, 1, 4, 1, 24, 25, 0), (2, 7, 6, 7, 2, 4, 0, 20, 25, 1), (2, 7, 2, 6, 0, 4, 1, 40, 25, 2), (2, 7, 4, 5, 1, 4, 1, 55, 25, 0), (2, 7, 2, 7, 0, 4, 1, 54, 25, 3), (2, 7, 5, 7, 1, 4, 0, 40, 25, 2), (4, 7, 4, 3, 1, 0, 1, 65, 38, 3), (2, 7, 4, 7, 2, 4, 1, 25, 7, 0), (2, 7, 3, 4, 2, 4, 1, 77, 25, 1), (2, 7, 2, 7, 3, 1, 0, 5, 39, 0), (2, 7, 2, 2, 0, 2, 1, 40, 13, 3), (2, 7, 4, 7, 1, 4, 1, 40, 38, 1), (2, 7, 6, 7, 4, 4, 0, 35, 31, 3), (2, 7, 2, 4, 0, 4, 1, 40, 38, 3), (4, 7, 2, 11, 2, 4, 1, 40, 38, 0), (2, 7, 4, 8, 1, 4, 0, 40, 12, 0), (2, 7, 2, 5, 0, 4, 1, 40, 25, 2), (1, 7, 2, 7, 0, 4, 1, 32, 25, 3), (2, 7, 2, 6, 0, 4, 1, 40, 25, 1), (2, 7, 4, 7, 2, 4, 0, 40, 12, 1), (2, 7, 2, 7, 0, 4, 1, 40, 38, 2), (2, 7, 4, 6, 1, 4, 1, 24, 25, 0), (2, 7, 5, 4, 1, 2, 1, 50, 38, 3), (2, 7, 2, 13, 0, 4, 1, 50, 38, 3), (2, 7, 2, 2, 0, 4, 1, 40, 25, 1), (2, 7, 4, 4, 1, 4, 1, 30, 7, -1), (2, 7, 4, 8, 1, 4, 0, 40, 25, 0), (2, 7, 4, 7, 4, 4, 0, 48, 7, 1), (2, 7, 2, 9, 0, 4, 1, 45, 38, 1), (2, 7, 4, 7, 2, 3, 0, 40, 7, 1), (2, 7, 2, 7, 0, 4, 1, 35, 25, 3), (2, 7, 4, 5, 2, 4, 1, 52, 25, -1), (2, 7, 4, 4, 1, 4, 1, 40, 25, 1), (2, 7, 2, 6, 0, 4, 1, 40, 21, 2), (2, 7, 2, 13, 0, 4, 1, 50, 38, 3), (2, 7, 4, 11, 3, 4, 0, 24, 38, 1), (1, 7, 4, 7, 1, 0, 0, 20, 38, 2), (2, 7, 5, 8, 2, 4, 0, 40, 25, 3), (2, 7, 4, 4, 1, 3, 1, 66, 25, 0), (2, 7, 2, 2, 0, 4, 1, 40, 25, 3), (2, 7, 2, 7, 0, 4, 1, 40, 25, 3), (2, 7, 2, 5, 0, 4, 1, 40, 25, 1), (2, 7, 2, 7, 2, 4, 1, 40, 8, 0), (2, 7, 4, 5, 1, 4, 1, 55, 25, -1), (2, 7, 2, 6, 0, 4, 1, 40, 25, 2), (2, 7, 4, 6, 2, 4, 1, 40, 25, -1), (2, 7, 2, 11, 0, 4, 1, 50, 25, 2), (2, 7, 2, 13, 0, 4, 1, 40,  ...

# %%
label = e9
label
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(features, label, test_size=0.3,random_state=12000)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)

# %%
from sklearn import metrics

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
gnb_acc=metrics.accuracy_score(y_test, y_pred)
# Out:
# Accuracy: 0.7595712098009189

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,confusion_matrix,f1_score
print("precision score : "+str(precision_score(y_test, y_pred))) # tp/tp+fp
print("accuracy score : "+str(accuracy_score(y_test, y_pred))) # total correct 
print("recall score : "+str(recall_score(y_test, y_pred)))   # tp/tp+fn
print("f1 score : "+str(f1_score(y_test, y_pred))) 
average_precision=precision_score(y_test, y_pred)
# Out:
# precision score : 0.513671875
# accuracy score : 0.7595712098009189
# recall score : 0.672978505629478
# f1 score : 0.5826318121400089

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt



precision, recall, _ = precision_recall_curve(y_test, y_pred)

plt.step(recall, precision, color='b', alpha=0.2,where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, '2-class Precision-Recall curve: AP=0.51')

# %%
from sklearn.tree import DecisionTreeClassifier 
clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
clf_acc=metrics.accuracy_score(y_test, y_pred)
# Out:
# Accuracy: 0.7969627360898418

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,confusion_matrix,f1_score
print("precision score : "+str(precision_score(y_test, y_pred))) # tp/tp+fp
print("accuracy score : "+str(accuracy_score(y_test, y_pred))) # total correct 
print("recall score : "+str(recall_score(y_test, y_pred)))   # tp/tp+fn
print("f1 score : "+str(f1_score(y_test, y_pred))) 
average_precision=precision_score(y_test, y_pred)
# Out:
# precision score : 0.6036550542547116
# accuracy score : 0.7969627360898418
# recall score : 0.5409416581371546
# f1 score : 0.5705802968960864

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt



precision, recall, _ = precision_recall_curve(y_test, y_pred)

plt.step(recall, precision, color='b', alpha=0.2,where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(average_precision))
# Out:
# Text(0.5, 1.0, '2-class Precision-Recall curve: AP=0.60')

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
knn_acc=metrics.accuracy_score(y_test, y_pred)
# Out:
# Accuracy: 0.790454313425217

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,confusion_matrix,f1_score
print("precision score : "+str(precision_score(y_test, y_pred))) # tp/tp+fp
print("accuracy score : "+str(accuracy_score(y_test, y_pred))) # total correct 
print("recall score : "+str(recall_score(y_test, y_pred)))   # tp/tp+fn
print("f1 score : "+str(f1_score(y_test, y_pred)))
average_precision=precision_score(y_test, y_pred)
# Out:
# precision score : 0.5807453416149069
# accuracy score : 0.790454313425217
# recall score : 0.5742067553735927
# f1 score : 0.5774575398867731

# %%
predicted= clf.predict([[2, 7, 2, 2, 1, 4, 1, 32, 25, 1]])
print("Predicted Value:", predicted)
# Out:
# Predicted Value: [0]

# %%
y=[gnb_acc,clf_acc,knn_acc]
x=['Naive bayes', 'Decision Tree', 'K-nearest neighbour']
plt.bar(x,y)
plt.show()
